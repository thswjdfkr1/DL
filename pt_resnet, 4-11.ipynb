# %% [markdown]
# ## 실습내용
# -----
# - ResNet 사용하여 이미지를 학습하고 10개의 카테고리를 갖는 이미지를 분류하는 이미지 분류기를 생성

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/fastcam/Part 4. 인공지능의 이해 Lv.3 _ 인공지능의 이해를 바탕으로 한 실습/resnet
# Out:
# /content/drive/MyDrive/fastcam/Part 4. 인공지능의 이해 Lv.3 _ 인공지능의 이해를 바탕으로 한 실습/resnet

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# !python main.py
# Out:
# epoch:0
# Loss:  9.371581358909607
# Loss:  2.91973331451416
# Loss:  2.5180934119224547
# Train Loss: 4.321985180725527, Test accuracy: 18.48%
# epoch:1
# Loss:  2.289118781089783
# Loss:  2.2219155192375184
# Loss:  2.1972937870025633
# Train Loss: 2.220886378032167, Test accuracy: 21.0%
# epoch:2
# Loss:  2.185293617248535
# Loss:  2.1605821466445922
# Loss:  2.144591362476349
# Train Loss: 2.155824551801852, Test accuracy: 22.220000000000002%
# epoch:3
# Loss:  2.1641988587379455
# Loss:  2.1256026136875152
# Loss:  2.119493056535721
# Train Loss: 2.1255103499078385, Test accuracy: 22.650000000000002%
# epoch:4
# Loss:  2.133931818008423
# Loss:  2.08563444852829
# Loss:  2.0799838972091673
# Train Loss: 2.0881071999249863, Test accuracy: 24.09%

# %% [markdown]
# ### argparse
# ----

# %%
# !python main_args.py -e 5
# Out:
# Namespace(gpu=0, momentum=0.9, weight_decay=0.0001, factor=0.1, lr=0.1, batch_size=128, patience=5, max_epoch=5)
# epoch:0
# Loss:  9.65944432735443
# Loss:  3.2700461244583128
# Loss:  2.470952026844025
# Train Loss: 4.470823611139946, Test accuracy: 18.34%
# epoch:1
# Loss:  2.240246591567993
# Loss:  2.1718742418289185
# Loss:  2.137404661178589
# Train Loss: 2.1628938099307478, Test accuracy: 23.68%
# epoch:2
# Loss:  2.110252938270569
# Loss:  2.0527781367301943
# Loss:  2.04092480301857
# Train Loss: 2.0521851290217445, Test accuracy: 25.929999999999996%
# epoch:3
# Loss:  2.013064373731613
# Loss:  1.9888561832904816
# Loss:  1.9709266078472139
# Train Loss: 1.9788034392134917, Test accuracy: 27.96%
# epoch:4
# Loss:  1.968288813829422
# Loss:  1.9382766807079315
# Loss:  1.91621133685112
# Train Loss: 1.9278957541946256, Test accuracy: 28.249999999999996%

# %%
# !python test.py

# %%
# !python train.py

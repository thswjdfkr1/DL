# %% [markdown]
# # IMDB Movie Review Analysis

# %% [markdown]
# ## 실습 목표
# ----
# - 자연어 처리를 위한 주요 신경망의 사용법을 이해
# - 영화 리뷰평의 긍정/부정을 판단하기 위한 감정분석 분류 모델을 생성

# %% [markdown]
# ## 문제 정의
# ----
# - binary classifier(positive or negative)

# %% [markdown]
# ### 3. tqdm
#
# - iterable을 감싸서 진행률을 표시할 때 사용
# - 학습 과정의 iteration에서 진행률을 표시할 때 사용

# %%
from tqdm import tqdm
import time

for i in tqdm(range(100)):
    time.sleep(0.05)
    pass
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.52it/s]

# %% [markdown]
# ### 4. Early stop

# %% [markdown]
# #### [Step1] Load libraries & Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch import nn
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader

import os
from tqdm import tqdm
tqdm.pandas()
from collections import Counter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/github/deeplearning
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/github/deeplearning'
# /content

# %%
data = pd.read_csv('/content/drive/MyDrive/fastcam/Part 4. 인공지능의 이해 Lv.3 _ 인공지능의 이해를 바탕으로 한 실습/dataset/exercise4.csv')
data.head()
# Out:
#                                            processed  label
# 0  One reviewer mentioned watching Oz episode hoo...      1
# 1  A wonderful little production . The filming te...      1
# 2  I thought wonderful way spend time hot summer ...      1
# 3  Basically family little boy Jake think zombie ...      0
# 4  Petter Mattei Love Time Money visually stunnin...      1

# %%
data['processed'] = data['processed'].str.lower().replace(r"[^a-zA-Z ]", "", regex=True)

# %%
data['processed'][0]
# Out:
# 'one reviewer mentioned watching oz episode hooked  they right  exactly happened  the first thing struck oz brutality unflinching scene violence  set right word go  trust  show faint hearted timid  this show pull punch regard drug  sex violence  its hardcore  classic use word  it called oz nickname given oswald maximum security state penitentary  it focus mainly emerald city  experimental section prison cell glass front face inwards  privacy high agenda  em city home many   aryans  muslims  gangsta  latinos  christians  italians  irish     scuffle  death stare  dodgy dealing shady agreement never far away  i would say main appeal show due fact go show dare  forget pretty picture painted mainstream audience  forget charm  forget romance    oz mess around  the first episode i ever saw struck nasty surreal  i say i ready  i watched  i developed taste oz  got accustomed high level graphic violence  not violence  injustice crooked guard sold nickel  inmate kill order get away  well mannered  middle class inmate turned prison bitch due lack street skill prison experience watching oz  may become comfortable uncomfortable viewing     thats get touch darker side '

# %% [markdown]
# ##### 사전생성

# %%
# 문장에 포함된 단어 토큰화
reviews = data['processed'].values
words = ' '.join(reviews).split()
words[:10]
# Out:
# ['one',
#  'reviewer',
#  'mentioned',
#  'watching',
#  'oz',
#  'episode',
#  'hooked',
#  'they',
#  'right',
#  'exactly']

# %%
counter = Counter(words)
vocab = sorted(counter, key=counter.get, reverse=True)
int2word = dict(enumerate(vocab, 1))
int2word[0] = '<PAD>'
word2int = {word: id for id, word in int2word.items()}
word2int
# Out:
# {'i': 1,
#  'movie': 2,
#  'film': 3,
#  'the': 4,
#  'one': 5,
#  'like': 6,
#  'it': 7,
#  'time': 8,
#  'this': 9,
#  'good': 10,
#  'character': 11,
#  'story': 12,
#  'even': 13,
#  'get': 14,
#  'would': 15,
#  'make': 16,
#  'see': 17,
#  'really': 18,
#  'scene': 19,
#  'well': 20,
#  'much': 21,
#  'bad': 22,
#  'people': 23,
#  'great': 24,
#  'also': 25,
#  'first': 26,
#  'show': 27,
#  'way': 28,
#  'made': 29,
#  'thing': 30,
#  'could': 31,
#  'life': 32,
#  'think': 33,
#  'go': 34,
#  'but': 35,
#  'know': 36,
#  'watch': 37,
#  'and': 38,
#  'love': 39,
#  'plot': 40,
#  'two': 41,
#  'actor': 42,
#  'many': 43,
#  'seen': 44,
#  'a': 45,
#  'say': 46,
#  'year': 47,
#  'never': 48,
#  'end': 49,
#  'acting': 50,
#  'look': 51,
#  'best': 52,
#  'little': 53,
#  'in': 54,
#  'there': 55,
#  'ever': 56,
#  'man': 57,
#  'better': 58,
#  'take': 59,
#  'if': 60,
#  'come': 61,
#  'work': 62,
#  'still': 63,
#  'he': 64,
#  'part': 65,
#  'something': 66,
#  'find': 67,
#  'director': 68,
#  'want': 69,
#  'back': 70,
#  'give': 71,
#  'lot': 72,
#  'real': 73,
#  'watching': 74,
#  'guy': 75,
#  'performance': 76,
#  'play': 77,
#  'old': 78,
#  'funny': 79,
#  'though': 80,
#  'woman': 81,
#  'another': 82,
#  'actually': 83,
#  'nothing': 84,
#  'role': 85,
#  'going': 86,
#  'new': 87,
#  'every': 88,
#  'point': 89,
#  'world': 90,
#  'girl': 91,
#  'day': 92,
#  'cast': 93,
#  'horror': 94,
#  'comedy': 95,
#  'minute': 96,
#  'thought': 97,
#  'u': 98,
#  'feel': 99,
#  'fact': 100,
#  'quite': 101,
#  'pretty': 102,
#  'got': 103,
#  'around': 104,
#  'action': 105,
#  'seems': 106,
#  'young': 107,
#  'you': 108,
#  'star': 109,
#  'big': 110,
#  'however': 111,
#  'enough': 112,
#  'long': 113,
#  'right': 114,
#  'line': 115,
#  'what': 116,
#  'may': 117,
#  'as': 118,
#  'they': 119,
#  'bit': 120,
#  'series': 121,
#  'must': 122,
#  'fan': 123,
#  'music': 124,
#  'set': 125,
#  'without': 126,
#  'friend': 127,
#  'original': 128,
#  'saw': 129,
#  'family': 130,
#  'always': 131,
#  'almost': 132,
#  'script': 133,
#  'interesting': 134,
#  'done': 135,
#  'whole': 136,
#  'least': 137,
#  'try': 138,
#  'far': 139,
#  'shot': 140,
#  'kind': 141,
#  'kid': 142,
#  'last': 143,
#  'making': 144,
#  'might': 145,
#  'anything': 146,
#  'effect': 147,
#  'since': 148,
#  'reason': 149,
#  'tv': 150,
#  'start': 151,
#  'book': 152,
#  'probably': 153,
#  'that': 154,
#  'so': 155,
#  'put': 156,
#  'place': 157,
#  'away': 158,
#  'yet': 159,
#  'moment': 160,
#  'fun': 161,
#  'anyone': 162,
#  'she': 163,
#  'worst': 164,
#  'not': 165,
#  'child': 166,
#  'let': 167,
#  'sure': 168,
#  'rather': 169,
#  'hard': 170,
#  'idea': 171,
#  'audience': 172,
#  'played': 173,
#  'screen': 174,
#  'found': 175,
#  'need': 176,
#  'tell': 177,
#  'looking': 178,
#  'turn': 179,
#  'although': 180,
#  'especially': 181,
#  'believe': 182,
#  'dvd': 183,
#  'ending': 184,
#  'course': 185,
#  'episode': 186,
#  'trying': 187,
#  'when': 188,
#  'mean': 189,
#  'everything': 190,
#  'job': 191,
#  'maybe': 192,
#  'three': 193,
#  'worth': 194,
#  'different': 195,
#  'someone': 196,
#  'war': 197,
#  'main': 198,
#  'sense': 199,
#  'american': 200,
#  'problem': 201,
#  'version': 202,
#  'money': 203,
#  'true': 204,
#  'watched': 205,
#  'keep': 206,
#  'everyone': 207,
#  'second': 208,
#  'all': 209,
#  'together': 210,
#  'help': 211,
#  'night': 212,
#  'high': 213,
#  'for': 214,
#  'mind': 215,
#  'half': 216,
#  'instead': 217,
#  'death': 218,
#  'said': 219,
#  'black': 220,
#  'boy': 221,
#  'special': 222,
#  'later': 223,
#  'house': 224,
#  'laugh': 225,
#  'hour': 226,
#  'wife': 227,
#  'john': 228,
#  'my': 229,
#  'seem': 230,
#  'beautiful': 231,
#  'left': 232,
#  'seeing': 233,
#  'short': 234,
#  'lead': 235,
#  'we': 236,
#  'excellent': 237,
#  'name': 238,
#  'le': 239,
#  'classic': 240,
#  'father': 241,
#  'sound': 242,
#  'else': 243,
#  'budget': 244,
#  'read': 245,
#  'face': 246,
#  'production': 247,
#  'viewer': 248,
#  'top': 249,
#  'piece': 250,
#  'used': 251,
#  'nice': 252,
#  'simply': 253,
#  'poor': 254,
#  'completely': 255,
#  'men': 256,
#  'eye': 257,
#  'home': 258,
#  'camera': 259,
#  'along': 260,
#  'human': 261,
#  'video': 262,
#  'dead': 263,
#  'no': 264,
#  'head': 265,
#  'song': 266,
#  'hollywood': 267,
#  'either': 268,
#  'school': 269,
#  'couple': 270,
#  'boring': 271,
#  'word': 272,
#  'low': 273,
#  'wrong': 274,
#  'picture': 275,
#  'hand': 276,
#  'enjoy': 277,
#  'use': 278,
#  'given': 279,
#  'full': 280,
#  'rest': 281,
#  'stupid': 282,
#  'next': 283,
#  'sex': 284,
#  'truly': 285,
#  'of': 286,
#  'writer': 287,
#  'awful': 288,
#  'hope': 289,
#  'run': 290,
#  'kill': 291,
#  'to': 292,
#  'person': 293,
#  'recommend': 294,
#  'style': 295,
#  'terrible': 296,
#  'game': 297,
#  'remember': 298,
#  'at': 299,
#  'title': 300,
#  'mother': 301,
#  'getting': 302,
#  'sort': 303,
#  'came': 304,
#  'understand': 305,
#  'case': 306,
#  'dialogue': 307,
#  'perhaps': 308,
#  'flick': 309,
#  'act': 310,
#  'wonderful': 311,
#  'playing': 312,
#  'care': 313,
#  'joke': 314,
#  'after': 315,
#  'small': 316,
#  'attempt': 317,
#  'others': 318,
#  'perfect': 319,
#  'sequence': 320,
#  'early': 321,
#  'often': 322,
#  'review': 323,
#  'fall': 324,
#  'written': 325,
#  'definitely': 326,
#  'drama': 327,
#  'art': 328,
#  'actress': 329,
#  'cinema': 330,
#  'quality': 331,
#  'example': 332,
#  'went': 333,
#  'finally': 334,
#  'feeling': 335,
#  'yes': 336,
#  'absolutely': 337,
#  'live': 338,
#  'killer': 339,
#  'oh': 340,
#  'certainly': 341,
#  'don': 342,
#  'lost': 343,
#  'liked': 344,
#  'become': 345,
#  'entertaining': 346,
#  'worse': 347,
#  'side': 348,
#  'loved': 349,
#  'car': 350,
#  'called': 351,
#  'waste': 352,
#  'white': 353,
#  'mr': 354,
#  'felt': 355,
#  'overall': 356,
#  'matter': 357,
#  'based': 358,
#  'entire': 359,
#  'supposed': 360,
#  'several': 361,
#  'direction': 362,
#  'son': 363,
#  'his': 364,
#  'beginning': 365,
#  'lack': 366,
#  'feature': 367,
#  'heart': 368,
#  'comment': 369,
#  'favorite': 370,
#  'dark': 371,
#  'fight': 372,
#  'why': 373,
#  'type': 374,
#  'then': 375,
#  'totally': 376,
#  'begin': 377,
#  'evil': 378,
#  'humor': 379,
#  'wanted': 380,
#  'murder': 381,
#  'seemed': 382,
#  'hero': 383,
#  'despite': 384,
#  'guess': 385,
#  'brother': 386,
#  'final': 387,
#  'voice': 388,
#  'while': 389,
#  'already': 390,
#  'change': 391,
#  'throughout': 392,
#  'now': 393,
#  'becomes': 394,
#  'relationship': 395,
#  'hit': 396,
#  'genre': 397,
#  'unfortunately': 398,
#  'able': 399,
#  'number': 400,
#  'meet': 401,
#  'history': 402,
#  'experience': 403,
#  'b': 404,
#  'some': 405,
#  'cut': 406,
#  'stop': 407,
#  'town': 408,
#  'today': 409,
#  'writing': 410,
#  'daughter': 411,
#  'fine': 412,
#  'michael': 413,
#  'god': 414,
#  'horrible': 415,
#  'close': 416,
#  'amazing': 417,
#  'city': 418,
#  'age': 419,
#  'group': 420,
#  'how': 421,
#  'move': 422,
#  'talent': 423,
#  'past': 424,
#  'call': 425,
#  'etc': 426,
#  'stuff': 427,
#  'enjoyed': 428,
#  'brilliant': 429,
#  'behind': 430,
#  'gave': 431,
#  'with': 432,
#  'event': 433,
#  'directed': 434,
#  'level': 435,
#  'late': 436,
#  'credit': 437,
#  'add': 438,
#  'situation': 439,
#  'theme': 440,
#  'save': 441,
#  'expect': 442,
#  'stand': 443,
#  'soon': 444,
#  'wonder': 445,
#  'power': 446,
#  'body': 447,
#  'on': 448,
#  'obviously': 449,
#  'score': 450,
#  'self': 451,
#  'sometimes': 452,
#  'chance': 453,
#  'thinking': 454,
#  'killed': 455,
#  'just': 456,
#  'decent': 457,
#  'view': 458,
#  'highly': 459,
#  'question': 460,
#  'blood': 461,
#  'anyway': 462,
#  'light': 463,
#  'known': 464,
#  'took': 465,
#  'heard': 466,
#  'happens': 467,
#  'except': 468,
#  'coming': 469,
#  'country': 470,
#  'wish': 471,
#  'element': 472,
#  'slow': 473,
#  'career': 474,
#  'documentary': 475,
#  'talk': 476,
#  'novel': 477,
#  'rating': 478,
#  'leave': 479,
#  'order': 480,
#  'police': 481,
#  'told': 482,
#  'interest': 483,
#  'monster': 484,
#  'extremely': 485,
#  'husband': 486,
#  'violence': 487,
#  'involved': 488,
#  'reality': 489,
#  'strong': 490,
#  'ok': 491,
#  'hilarious': 492,
#  'crap': 493,
#  'effort': 494,
#  'hell': 495,
#  'happen': 496,
#  'living': 497,
#  'particularly': 498,
#  'including': 499,
#  'looked': 500,
#  'cool': 501,
#  'opinion': 502,
#  'david': 503,
#  'us': 504,
#  'simple': 505,
#  'please': 506,
#  'musical': 507,
#  'is': 508,
#  'twist': 509,
#  'obvious': 510,
#  'happened': 511,
#  'complete': 512,
#  'gore': 513,
#  'serious': 514,
#  'sequel': 515,
#  'james': 516,
#  'deal': 517,
#  'room': 518,
#  'ago': 519,
#  'theater': 520,
#  'taken': 521,
#  'female': 522,
#  'shown': 523,
#  'robert': 524,
#  'english': 525,
#  'thriller': 526,
#  'seriously': 527,
#  'released': 528,
#  'lady': 529,
#  'opening': 530,
#  'value': 531,
#  'across': 532,
#  'alone': 533,
#  'none': 534,
#  'miss': 535,
#  'sad': 536,
#  'possible': 537,
#  'exactly': 538,
#  'saying': 539,
#  'sister': 540,
#  'cop': 541,
#  'usually': 542,
#  'cinematography': 543,
#  'dialog': 544,
#  'annoying': 545,
#  'running': 546,
#  'dream': 547,
#  'huge': 548,
#  'class': 549,
#  'open': 550,
#  'whose': 551,
#  'taking': 552,
#  'comic': 553,
#  'ridiculous': 554,
#  'stay': 555,
#  'major': 556,
#  'local': 557,
#  'middle': 558,
#  'important': 559,
#  'four': 560,
#  'dog': 561,
#  'started': 562,
#  'jack': 563,
#  'message': 564,
#  'zombie': 565,
#  'turned': 566,
#  'producer': 567,
#  'scary': 568,
#  'mostly': 569,
#  'team': 570,
#  'usual': 571,
#  'happy': 572,
#  'beyond': 573,
#  'silly': 574,
#  'hate': 575,
#  'attention': 576,
#  'somewhat': 577,
#  'talking': 578,
#  'knew': 579,
#  'rock': 580,
#  'disappointed': 581,
#  'surprise': 582,
#  'single': 583,
#  'strange': 584,
#  'apparently': 585,
#  'non': 586,
#  'television': 587,
#  'upon': 588,
#  'modern': 589,
#  'due': 590,
#  'basically': 591,
#  'cheap': 592,
#  'release': 593,
#  'figure': 594,
#  'from': 595,
#  'mention': 596,
#  'earth': 597,
#  'result': 598,
#  'member': 599,
#  'king': 600,
#  'image': 601,
#  'tale': 602,
#  'subject': 603,
#  'street': 604,
#  'crime': 605,
#  'clearly': 606,
#  'space': 607,
#  'parent': 608,
#  'ten': 609,
#  'season': 610,
#  'five': 611,
#  'british': 612,
#  'return': 613,
#  'drug': 614,
#  'french': 615,
#  'moving': 616,
#  'entertainment': 617,
#  'filmmaker': 618,
#  'fast': 619,
#  'straight': 620,
#  'mystery': 621,
#  'soundtrack': 622,
#  'predictable': 623,
#  'future': 624,
#  'die': 625,
#  'form': 626,
#  'viewing': 627,
#  'hold': 628,
#  'whether': 629,
#  'villain': 630,
#  'doubt': 631,
#  'george': 632,
#  'gun': 633,
#  'killing': 634,
#  'romantic': 635,
#  'easily': 636,
#  'enjoyable': 637,
#  'near': 638,
#  'appears': 639,
#  'break': 640,
#  'buy': 641,
#  's': 642,
#  'bring': 643,
#  'giving': 644,
#  'aspect': 645,
#  'similar': 646,
#  'supporting': 647,
#  'working': 648,
#  'clear': 649,
#  'within': 650,
#  'filmed': 651,
#  'showing': 652,
#  'bunch': 653,
#  'adult': 654,
#  'note': 655,
#  'dull': 656,
#  'western': 657,
#  'suspense': 658,
#  'doctor': 659,
#  'emotion': 660,
#  'storyline': 661,
#  'surprised': 662,
#  'easy': 663,
#  'sorry': 664,
#  'tried': 665,
#  'certain': 666,
#  'among': 667,
#  'setting': 668,
#  'named': 669,
#  'dance': 670,
#  'standard': 671,
#  'present': 672,
#  'period': 673,
#  'gone': 674,
#  'check': 675,
#  'force': 676,
#  'victim': 677,
#  'soldier': 678,
#  'general': 679,
#  'dr': 680,
#  'student': 681,
#  'using': 682,
#  'typical': 683,
#  'rent': 684,
#  'an': 685,
#  'oscar': 686,
#  'editing': 687,
#  'avoid': 688,
#  'th': 689,
#  'peter': 690,
#  'material': 691,
#  'richard': 692,
#  'fantastic': 693,
#  'who': 694,
#  'kept': 695,
#  'nearly': 696,
#  'realistic': 697,
#  'detail': 698,
#  'cartoon': 699,
#  'okay': 700,
#  'battle': 701,
#  'greatest': 702,
#  'its': 703,
#  'red': 704,
#  'famous': 705,
#  'animation': 706,
#  'imagine': 707,
#  'paul': 708,
#  'actual': 709,
#  'follow': 710,
#  'premise': 711,
#  'issue': 712,
#  'mark': 713,
#  'believable': 714,
#  'tom': 715,
#  'box': 716,
#  'brought': 717,
#  'wait': 718,
#  'truth': 719,
#  'romance': 720,
#  'somehow': 721,
#  'forget': 722,
#  'masterpiece': 723,
#  'male': 724,
#  'fit': 725,
#  'third': 726,
#  'copy': 727,
#  'offer': 728,
#  'most': 729,
#  'average': 730,
#  'america': 731,
#  'weak': 732,
#  'hear': 733,
#  'background': 734,
#  'sit': 735,
#  'escape': 736,
#  'pay': 737,
#  'stage': 738,
#  'society': 739,
#  'atmosphere': 740,
#  'deep': 741,
#  'york': 742,
#  'cover': 743,
#  'o': 744,
#  'cause': 745,
#  'fi': 746,
#  'her': 747,
#  'eventually': 748,
#  'gay': 749,
#  'learn': 750,
#  'sci': 751,
#  'imdb': 752,
#  'whatever': 753,
#  'expected': 754,
#  'particular': 755,
#  'lame': 756,
#  'indeed': 757,
#  'de': 758,
#  'poorly': 759,
#  'shame': 760,
#  'these': 761,
#  'free': 762,
#  'hot': 763,
#  'rate': 764,
#  'baby': 765,
#  'crew': 766,
#  'choice': 767,
#  'walk': 768,
#  'state': 769,
#  'by': 770,
#  'secret': 771,
#  'decided': 772,
#  'leaf': 773,
#  'party': 774,
#  'screenplay': 775,
#  'reading': 776,
#  'fire': 777,
#  'air': 778,
#  'difficult': 779,
#  'lee': 780,
#  'week': 781,
#  'needed': 782,
#  'beauty': 783,
#  'girlfriend': 784,
#  'footage': 785,
#  'focus': 786,
#  'acted': 787,
#  'unless': 788,
#  'emotional': 789,
#  'possibly': 790,
#  'island': 791,
#  'here': 792,
#  'sexual': 793,
#  'write': 794,
#  'accent': 795,
#  'alien': 796,
#  'forced': 797,
#  'became': 798,
#  'memorable': 799,
#  'e': 800,
#  'vampire': 801,
#  'd': 802,
#  'do': 803,
#  'otherwise': 804,
#  'nature': 805,
#  'forward': 806,
#  'plus': 807,
#  'match': 808,
#  'very': 809,
#  'touch': 810,
#  'lover': 811,
#  'bill': 812,
#  'cheesy': 813,
#  'location': 814,
#  'water': 815,
#  'or': 816,
#  'superb': 817,
#  'fantasy': 818,
#  'inside': 819,
#  'interested': 820,
#  'development': 821,
#  'perfectly': 822,
#  'animal': 823,
#  'weird': 824,
#  'previous': 825,
#  'badly': 826,
#  'adventure': 827,
#  'japanese': 828,
#  'mess': 829,
#  'crazy': 830,
#  'personal': 831,
#  't': 832,
#  'pick': 833,
#  'quickly': 834,
#  'total': 835,
#  'maker': 836,
#  'business': 837,
#  'towards': 838,
#  'disney': 839,
#  'spoiler': 840,
#  'front': 841,
#  'plan': 842,
#  'win': 843,
#  'company': 844,
#  'remake': 845,
#  'joe': 846,
#  'rich': 847,
#  'cry': 848,
#  'worked': 849,
#  'earlier': 850,
#  'incredibly': 851,
#  'shoot': 852,
#  'teen': 853,
#  'fear': 854,
#  'dumb': 855,
#  'studio': 856,
#  'brain': 857,
#  'unique': 858,
#  'realize': 859,
#  'project': 860,
#  'powerful': 861,
#  'list': 862,
#  'dramatic': 863,
#  'older': 864,
#  'era': 865,
#  'following': 866,
#  'success': 867,
#  'plenty': 868,
#  'directing': 869,
#  'amount': 870,
#  'ask': 871,
#  'creepy': 872,
#  'various': 873,
#  'cat': 874,
#  'appear': 875,
#  'term': 876,
#  'brings': 877,
#  'band': 878,
#  'century': 879,
#  'costume': 880,
#  'admit': 881,
#  'political': 882,
#  'apart': 883,
#  'store': 884,
#  'leading': 885,
#  'fairly': 886,
#  'memory': 887,
#  'portrayed': 888,
#  'spent': 889,
#  'wood': 890,
#  'co': 891,
#  'telling': 892,
#  'law': 893,
#  'trouble': 894,
#  'outside': 895,
#  'train': 896,
#  'fighting': 897,
#  'wasted': 898,
#  'william': 899,
#  'fails': 900,
#  'deserves': 901,
#  'portrayal': 902,
#  'throw': 903,
#  'chase': 904,
#  'c': 905,
#  'office': 906,
#  'meant': 907,
#  'concept': 908,
#  'drive': 909,
#  'creature': 910,
#  'create': 911,
#  'plain': 912,
#  'expecting': 913,
#  'missing': 914,
#  'ability': 915,
#  'spirit': 916,
#  'ended': 917,
#  'german': 918,
#  'manages': 919,
#  'language': 920,
#  'mistake': 921,
#  'agree': 922,
#  'cute': 923,
#  'player': 924,
#  'appearance': 925,
#  'stick': 926,
#  'recently': 927,
#  'channel': 928,
#  'attack': 929,
#  'talented': 930,
#  'caught': 931,
#  'odd': 932,
#  'large': 933,
#  'unlike': 934,
#  'depth': 935,
#  'hardly': 936,
#  'produced': 937,
#  'pace': 938,
#  'clever': 939,
#  'laughing': 940,
#  'italian': 941,
#  'award': 942,
#  'nudity': 943,
#  'public': 944,
#  'flat': 945,
#  'potential': 946,
#  'tension': 947,
#  'casting': 948,
#  'culture': 949,
#  'created': 950,
#  'color': 951,
#  'ghost': 952,
#  'missed': 953,
#  'pull': 954,
#  'master': 955,
#  'married': 956,
#  'wrote': 957,
#  'hole': 958,
#  'pure': 959,
#  'soul': 960,
#  'waiting': 961,
#  'control': 962,
#  'door': 963,
#  'van': 964,
#  'blue': 965,
#  'filled': 966,
#  'scott': 967,
#  'cold': 968,
#  'science': 969,
#  'respect': 970,
#  'incredible': 971,
#  'mentioned': 972,
#  'sadly': 973,
#  'visual': 974,
#  'familiar': 975,
#  'slightly': 976,
#  'speak': 977,
#  'considering': 978,
#  'died': 979,
#  'only': 980,
#  'sweet': 981,
#  'hair': 982,
#  'popular': 983,
#  'answer': 984,
#  'catch': 985,
#  'purpose': 986,
#  'post': 987,
#  'million': 988,
#  'la': 989,
#  'extra': 990,
#  'anti': 991,
#  'meaning': 992,
#  'gang': 993,
#  'decides': 994,
#  'social': 995,
#  'convincing': 996,
#  'college': 997,
#  'jane': 998,
#  'track': 999,
#  'taste': 1000,
#  ...}

# %% [markdown]
# ##### 리뷰 인코딩

# %%
reviews_enc = [[word2int[word] for word in review.split()] for review in tqdm(reviews)]
# Out:
# 100%|██████████| 50000/50000 [00:01<00:00, 27681.23it/s]

# %%
reviews_enc[0][:10]
# Out:
# [5, 1095, 972, 74, 2893, 186, 2982, 119, 114, 538]

# %%
data['processed'][0]
# Out:
# 'one reviewer mentioned watching oz episode hooked  they right  exactly happened  the first thing struck oz brutality unflinching scene violence  set right word go  trust  show faint hearted timid  this show pull punch regard drug  sex violence  its hardcore  classic use word  it called oz nickname given oswald maximum security state penitentary  it focus mainly emerald city  experimental section prison cell glass front face inwards  privacy high agenda  em city home many   aryans  muslims  gangsta  latinos  christians  italians  irish     scuffle  death stare  dodgy dealing shady agreement never far away  i would say main appeal show due fact go show dare  forget pretty picture painted mainstream audience  forget charm  forget romance    oz mess around  the first episode i ever saw struck nasty surreal  i say i ready  i watched  i developed taste oz  got accustomed high level graphic violence  not violence  injustice crooked guard sold nickel  inmate kill order get away  well mannered  middle class inmate turned prison bitch due lack street skill prison experience watching oz  may become comfortable uncomfortable viewing     thats get touch darker side '

# %%
word2int['one'], word2int['reviewer'], word2int['mentioned']
# Out:
# (5, 1095, 972)

# %%
data['encoded'] = reviews_enc

# %% [markdown]
# ##### 길이 맞춰주기

# %%
def pad_features(reviews, pad_id, seq_length=128):
    features = np.full((len(reviews), seq_length), pad_id, dtype=int)  # np.full((5, 3), 2)

    for i, row in enumerate(reviews):
        # if seq_length < len(row) then review will be trimmed
        features[i, :len(row)] = np.array(row)[:seq_length]

    return features

seq_length = 256
features = pad_features(reviews_enc, pad_id=word2int['<PAD>'], seq_length=seq_length)

assert len(features) == len(reviews_enc)
assert len(features[0]) == seq_length

# %%
labels = data['label'].to_numpy()
labels
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# ##### 데이터 분할

# %%
# train test split
train_size = .8
split_id = int(len(features) * train_size)
train_x, test_x, train_y, test_y = features[:split_id], features[split_id:], labels[:split_id], labels[split_id:]

split_id = int(len(train_x) * train_size)
train_x, valid_x, train_y, valid_y = train_x[:split_id], train_x[split_id:], train_y[:split_id], train_y[split_id:]
print('Train shape:{}, Valid shape: {}, Test shape: {}'.format(train_x.shape, valid_x.shape, test_x.shape))
print('Train shape:{}, Valid shape: {}, Test shape: {}'.format(train_y.shape, valid_y.shape, test_y.shape))
# Out:
# Train shape:(32000, 256), Valid shape: (8000, 256), Test shape: (10000, 256)
# Train shape:(32000,), Valid shape: (8000,), Test shape: (10000,)

# %% [markdown]
# #### [Step2] Create DataLoader

# %%
# set hyperparameter
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

lr = 0.001
batch_size = 128
vocab_size = len(word2int)
embedding_size = 256
dropout=0.25

epochs = 8
history = {
    'train_loss': [],
    'train_acc': [],
    'val_loss': [],
    'val_acc': [],
    'epochs': epochs
}
es_limit = 5
# Out:
# cuda

# %%
trainset = TensorDataset(torch.from_numpy(train_x), torch.from_numpy(train_y))
validset = TensorDataset(torch.from_numpy(valid_x), torch.from_numpy(valid_y))
testset = TensorDataset(torch.from_numpy(test_x), torch.from_numpy(test_y))

trainloader = DataLoader(trainset, shuffle=True, batch_size=batch_size)
valloader = DataLoader(validset, shuffle=True, batch_size=batch_size)
testloader = DataLoader(testset, shuffle=True, batch_size=batch_size)

# %% [markdown]
# #### [Step3] Set Network Structure

# %%
class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_size=400):
        super(LSTMClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_size)
        self.lstm = nn.LSTM(embedding_size, 512, 2, dropout=0.25, batch_first=True)
        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(512, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = x.long()
        x = self.embedding(x)
        o, _ =  self.lstm(x)
        o = o[:, -1, :]
        o = self.dropout(o)
        o = self.fc(o)
        o = self.sigmoid(o)

        return o

# %% [markdown]
# #### [Step4] Create Model instance

# %%
model = LSTMClassifier(vocab_size, embedding_size).to(device)
print(model)
# Out:
# LSTMClassifier(
#   (embedding): Embedding(96140, 256)
#   (lstm): LSTM(256, 512, num_layers=2, batch_first=True, dropout=0.25)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# #### [Step5] Model compile

# %%
criterion = nn.BCELoss()
optim = Adam(model.parameters(), lr=lr)

# %% [markdown]
# #### [Step6] Set train loop

# %%
def train(model, trainloader):
    model.train()

    train_loss = 0
    train_acc = 0

    for id, (X, y) in enumerate(trainloader):
        X, y = X.to(device), y.to(device)
        optim.zero_grad()
        y_pred = model(X)
        loss = criterion(y_pred.squeeze(), y.float())
        loss.backward()
        optim.step()

        train_loss += loss.item()
        y_pred = torch.tensor([1 if i == True else 0 for i in y_pred > 0.5], device=device)
        equals = y_pred == y
        acc = torch.mean(equals.type(torch.FloatTensor))
        train_acc += acc.item()

    history['train_loss'].append(train_loss / len(trainloader))
    history['train_acc'].append(train_acc / len(trainloader))

    return train_loss, train_acc

# %% [markdown]
# #### [Step7] Set test loop

# %%
def validation(model, valloader):
    model.eval()

    val_loss = 0
    val_acc = 0

    with torch.no_grad():
        for id, (X, y) in enumerate(valloader):
            X, y = X.to(device), y.to(device)
            y_pred = model(X)
            loss = criterion(y_pred.squeeze(), y.float())

            val_loss += loss.item()

            y_pred = torch.tensor([1 if i == True else 0 for i in y_pred > 0.5], device=device)
            equals = y_pred == y
            acc = torch.mean(equals.type(torch.FloatTensor))
            val_acc += acc.item()

        history['val_loss'].append(val_loss / len(valloader))
        history['val_acc'].append(val_acc / len(valloader))

    return val_loss, val_acc

# %% [markdown]
# #### [Step8] Run model

# %%
# train loop
epochloop = tqdm(range(epochs), desc='Training')

# early stop trigger
es_trigger = 0
val_loss_min = torch.inf

for e in epochloop:
    train_loss, train_acc = train(model, trainloader)
    val_loss, val_acc = validation(model, valloader)
    epochloop.write(f'Epoch[{e+1}/{epochs}] Train Loss: {train_loss / len(trainloader):.3f}, Train Acc: {train_acc / len(trainloader):.3f}, Val Loss: {val_loss / len(valloader):.3f}, Val Acc: {val_acc / len(valloader):.3f}')

    # save model if validation loss decrease
    if val_loss / len(valloader) <= val_loss_min:
        torch.save(model.state_dict(), './sentiment_lstm.pt')
        val_loss_min = val_loss / len(valloader)
        es_trigger = 0
    else:
        es_trigger += 1

    # early stop
    if es_trigger >= es_limit:
        epochloop.write(f'Early stopped at Epoch-{e+1}')
        history['epochs'] = e+1
        break
# Out:
# Training:   0%|          | 0/8 [01:06<?, ?it/s]
# Epoch[1/8] Train Loss: 0.694, Train Acc: 0.502, Val Loss: 0.693, Val Acc: 0.502
# Training:  12%|█▎        | 1/8 [02:19<07:48, 66.98s/it]
# Epoch[2/8] Train Loss: 0.695, Train Acc: 0.497, Val Loss: 0.693, Val Acc: 0.512
# Training:  38%|███▊      | 3/8 [03:32<05:57, 71.45s/it]
# Epoch[3/8] Train Loss: 0.694, Train Acc: 0.504, Val Loss: 0.694, Val Acc: 0.502
# Training:  50%|█████     | 4/8 [04:44<04:47, 71.81s/it]
# Epoch[4/8] Train Loss: 0.693, Train Acc: 0.504, Val Loss: 0.693, Val Acc: 0.515
# Training:  62%|██████▎   | 5/8 [05:57<03:36, 72.03s/it]
# Epoch[5/8] Train Loss: 0.693, Train Acc: 0.504, Val Loss: 0.693, Val Acc: 0.513
# Training:  62%|██████▎   | 5/8 [07:09<03:36, 72.03s/it]
# Epoch[6/8] Train Loss: 0.693, Train Acc: 0.509, Val Loss: 0.693, Val Acc: 0.499
# Training:  88%|████████▊ | 7/8 [08:22<01:12, 72.33s/it]
# Epoch[7/8] Train Loss: 0.686, Train Acc: 0.518, Val Loss: 0.698, Val Acc: 0.495
# Training: 100%|██████████| 8/8 [09:35<00:00, 71.89s/it]
# Epoch[8/8] Train Loss: 0.669, Train Acc: 0.528, Val Loss: 0.706, Val Acc: 0.512

# %%
# plot loss
plt.figure(figsize=(6, 4))
plt.plot(range(history['epochs']), history['train_acc'], label='Train Acc')
plt.plot(range(history['epochs']), history['val_acc'], label='Val Acc')
plt.legend()
plt.show()

# %%
# plot loss
plt.figure(figsize=(6, 4))
plt.plot(range(history['epochs']), history['train_loss'], label='Train Loss')
plt.plot(range(history['epochs']), history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model.eval()

# input_sentence = str(input("문장을 입력하세요: "))
input_sentence = 'I love this moive'
tokens = input_sentence.split()
indexed_tokens = [word2int.get(word, word2int['<PAD>']) for word in tokens]
input_tensor = torch.tensor(indexed_tokens).unsqueeze(0).to(device)

print("토큰화된 인덱스:", indexed_tokens)
print("입력 텐서:", input_tensor)
# Out:
# 토큰화된 인덱스: [0, 39, 9, 55451]
# 입력 텐서: tensor([[    0,    39,     9, 55451]], device='cuda:0')

# %%
with torch.no_grad():
    output = model(input_tensor)
    _, predicted = torch.max(output, 1)

    print(f"모델 출력: {output}")
    print(f"예측된 클래스: {predicted.item()}")

if predicted.item() == 1:
    print("긍정적인 문장")
else:
    print("부정적인 문장")
# Out:
# 모델 출력: tensor([[0.7899]], device='cuda:0')
# 예측된 클래스: 0
# 부정적인 문장
